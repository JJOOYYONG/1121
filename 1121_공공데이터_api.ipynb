# %%
import os
import sys
import urllib.request
import datetime
import time
import json

import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager,rc

# %%
def get_request_url(url):
    req=urllib.request.Request(url)
    try:
        response=urllib.request.urlopen(req)
        if response.getcode()==200:
            print("[%s] Url Request Success" % datetime.datetime.now())
            return response.read().decode('utf-8')

    except Exception as e:
        print(e)
        print("[%s] Error for URL:%s" %(datetime.datetime.now(),url))
        return None

# %%
def getNatVisitor(yyyymm,nat_cd,ed_cd):
    end_point="http://openapi.tour.go.kr/openapi/service/EdrcntTourismStatsService/getEdrcntTourismStatsList"
    access_key="ZlQL419D9IcCoR5oBoHiu0ELHc%2FGUF6w6C6Zucbn7ggF%2Bai2Azd9ATBYDaGJhqvM%2Fr%2FA1Bw5p9y3pqVKI1Z0Ng%3D%3D"
    
    parameters = "?_type=json&serviceKey="+access_key
    parameters += "&YM="+yyyymm
    parameters += "&NAT_CD="+nat_cd
    parameters += "&ED_CD="+ed_cd
    
    url = end_point + parameters
    
    retData = get_request_url(url)
    
    if(retData==None):
        return None
    else:
        return json.loads(retData)

# %%
def main():
    
    jsonResult=[]
    
    national_code ="275"
    ed_cd="E"
    
    nStartYear=2011
    nEndYear=2017
    krName=""
    
    for year in range(nStartYear, nEndYear):
        for month in range(1,13):
            
            yyyymm="{0}{1:0>2}".format(str(year),str(month))
            
            jsonData = getNatVisitor(yyyymm,national_code,ed_cd)
            
            print(json.dumps(jsonData,
                            indent=4,sort_keys=True,
                            ensure_ascii=False))
            
            if (jsonData['response']['header']['resultMsg'] == 'OK'):
                krName = jsonData['response']['body']['items']['item']["natKorNm"]
                krName = krName.replace(' ', '')
                iTotalVisit = jsonData['response']['body']['items']['item']["num"]
                print('%s_%s : %s' %(krName, yyyymm, iTotalVisit))
                jsonResult.append({'nat_name': krName, 'nat_cd': national_code,
                                 'yyyymm': yyyymm, 'visit_cnt': iTotalVisit})
        
        cnVisit=[]
        VisitYM=[]
        index=[]
        i=0
        for item in jsonResult:
            index.append(i)
            cnVisit.append(item['visit_cnt'])
            VisitYM.append(item['yyyymm'])
            i=i+1
        with open('%s(%s)_해외방문객정보_%d_%d.json'
                  %(krName,national_code,nStartYear,nEndYear-1),'w',encoding='utf8') as outfile:
            retJson = json.dumps(jsonResult,indent=4,sort_keys=True,endsure_ascii=False)
            outfile.write(retJson)
    
    font_location = "c:/Windows/fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=font_location).get_name()
    matplotlib.rc('font', family=font_name)

    plt.xticks(index, VisitYM)
    plt.plot(index, cnVisit)
    plt.xlabel('방문월')
    plt.ylabel('방문객수')
    plt.grid(True)
    plt.show()           
    
if __name__ == '__main__':
    main()
# Out:
# [2019-11-21 15:31:53.943102] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 44152,
#                     "rnum": 1,
#                     "ym": 201101
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201101 : 44152
# [2019-11-21 15:31:53.968102] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 43500,
#                     "rnum": 1,
#                     "ym": 201102
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201102 : 43500
# [2019-11-21 15:31:53.993080] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 54135,
#                     "rnum": 1,
#                     "ym": 201103
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201103 : 54135
# [2019-11-21 15:31:54.018962] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 58220,
#                     "rnum": 1,
#                     "ym": 201104
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201104 : 58220
# [2019-11-21 15:31:54.043364] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 61077,
#                     "rnum": 1,
#                     "ym": 201105
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201105 : 61077
# [2019-11-21 15:31:54.068483] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 61208,
#                     "rnum": 1,
#                     "ym": 201106
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201106 : 61208
# [2019-11-21 15:31:54.096992] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 60522,
#                     "rnum": 1,
#                     "ym": 201107
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201107 : 60522
# [2019-11-21 15:31:54.126026] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 57817,
#                     "rnum": 1,
#                     "ym": 201108
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201108 : 57817
# [2019-11-21 15:31:54.156011] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 56103,
#                     "rnum": 1,
#                     "ym": 201109
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201109 : 56103
# [2019-11-21 15:31:54.183595] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 65158,
#                     "rnum": 1,
#                     "ym": 201110
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201110 : 65158
# [2019-11-21 15:31:54.208956] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 51094,
#                     "rnum": 1,
#                     "ym": 201111
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201111 : 51094
# [2019-11-21 15:31:54.235409] Url Request Success
# {
#     "response": {
#         "body": {
#             "items": {
#                 "item": {
#                     "ed": "방한외래관광객",
#                     "edCd": "E",
#                     "natCd": 275,
#                     "natKorNm": "미  국",
#                     "num": 48517,
#                     "rnum": 1,
#                     "ym": 201112
#                 }
#             },
#             "numOfRows": 10,
#             "pageNo": 1,
#             "totalCount": 1
#         },
#         "header": {
#             "resultCode": "0000",
#             "resultMsg": "OK"
#         }
#     }
# }
# 미국_201112 : 48517
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a81d2465c130> in <module>
#      55
#      56 if __name__ == '__main__':
# ---> 57     main()
#
# <ipython-input-5-a81d2465c130> in main()
#      40         with open('%s(%s)_해외방문객정보_%d_%d.json'
#      41                   %(krName,national_code,nStartYear,nEndYear-1),'w',encoding='utf8') as outfile:
# ---> 42             retJson = json.dumps(jsonResult,indent=4,sort_keys=True,endsure_ascii=False)
#      43             outfile.write(retJson)
#      44
#
# ~\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237         separators=separators, default=default, sort_keys=sort_keys,
# --> 238         **kw).encode(obj)
#     239
#     240
#
# TypeError: __init__() got an unexpected keyword argument 'endsure_ascii'
